# %%
a = 4
b = -5
t = (a < b) or not (a == b)
t
# Out:
# True

# %%
a = 8
b = 4
c = 16
d = b + c / 2
print(f'd = {d}')
e = b + a / (c - a)
print(f'e = {e}')
f = d - c / b / b
print(f'f = {f}')
f = d + e - f
print(f'f = {f}')
f
# Out:
# d = 12.0
# e = 5.0
# f = 11.0
# f = 6.0
# 6.0

# %%
n = 25
s = 0
for i in range(1, n):
    if(i % 4 == 0):
        print(f'{s + i} = {s} + {i}')
        s = s + i
s
# Out:
# 4 = 0 + 4
# 12 = 4 + 8
# 24 = 12 + 12
# 40 = 24 + 16
# 60 = 40 + 20
# 84 = 60 + 24
# 84

# %%
n = 45
s = 0
for i in range(5, n):
    if(i % 2 == 0):
        if(i % 5 == 0):
            s = s + 1
            print(s)
s
# Out:
# 1
# 2
# 3
# 4
# 4

# %%
s = 50
i = -1
n = 9
while(i != n):
    print(f'{s - 2 * i} = {s} - 2 * {i}')
    s = s - 2 * i
    i = i + 2
s
# Out:
# 52 = 50 - 2 * -1
# 50 = 52 - 2 * 1
# 44 = 50 - 2 * 3
# 34 = 44 - 2 * 5
# 20 = 34 - 2 * 7
# 20

# %%
s = 0
n = 5
i = 0
while(n < 50):
    i = i + 1
    s = s + n
    n = n + n
    print(i, s, n)
i
# Out:
# 1 5 10
# 2 15 20
# 3 35 40
# 4 75 80
# 4

# %%
a = 63
if(a % 2 == 0):
    print(a / 2)
else:
    print(2 * a)
# Out:
# 126

# %%
a = 6
b = 2
if(a > b):
    print(a / b)
else:
    print(b / a)
# Out:
# 3.0
